# %%
import numpy as np
from numpy.linalg import multi_dot,inv,pinv,norm,eig
import scipy
from scipy.linalg import null_space
import cvxpy as cp
import pandas as pd
import math

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rc
from collections import defaultdict

import pv_solver as pv
import numpy.polynomial.polynomial as poly
import mosek

# %%
G = pd.read_csv("20111001_data.csv", header = 0)
# fig, (ax) = plt.subplots(figsize=(10,5))
# ax.plot(G["s1"].iloc[7000:8000])
# fig, (ax) = plt.subplots(figsize=(10,5))
# ax.plot(G["s6"].iloc[7000:8000])
# fig, (ax) = plt.subplots(figsize=(10,5))
# ax.plot(G["s8"].iloc[7000:8000])
G1 = G["s1"].iloc[7000:8000].to_numpy().reshape(-1)
G6 = G["s6"].iloc[7000:8000].to_numpy().reshape(-1)
G8 = G["s8"].iloc[7000:8000].to_numpy().reshape(-1)

PV = pv.pv_panel(10,10)
# print(PV.find_opt(1000,30+273))
SOS = pv.sos_tracker()
vopt = PV.find_opt(1000,30+273)[1]
I,V = np.array([]),np.array([])
G = 1000
T = 30+273
for v in np.arange(220,240,0.5):
    i = PV.solve_i(G,T,10,v)[0]
    I = np.append(I,i)
    V = np.append(V,v)
SOS.buffer_I = I
SOS.buffer_V = V
SOS.solve_sos()
SOS.estimate(I[-1:],V[-1:])
G = 1050
T = 28+273
X = []
for v in np.arange(240,260,0.5):
    i = PV.solve_i(G,T,10,v)[0]
    I = np.append(I,i)
    V = np.append(V,v)
    SOS.buffer_I = I
    SOS.buffer_V = V
    SOS.solve_sos()
    x = SOS.estimate(I[-1:],V[-1:])
    X.append(x)
    p = 17740
    pest,vest = SOS.track(p,200)
    print(vest)
    iest = PV.solve_i(G,T,10,vest)[0]
    print(vest*iest,pest,p)
    
# SOS.update_curve(I,V)
# print(SOS.track(13000,200))
# for k in np.arange(-10,10,0.1):
#     v = vopt+k
#     i = PV.solve_i(1000,30+273,10,v)[0]
#     print(i)
#     SOS.update_curve(np.array([i]),np.array([v]))
# SOS.track(13000,200)

# print(PV.solve_i(1200,30+273,10,100)[0]*100)
# print(PV.solve_i(1200,30+273,10,250)[0]*250)

# P1max,P6max,P8max = [],[],[]
# for k in range(G6.shape[0]): 
#     P1max.append([k+0.01,PV.find_opt(G1[k],30+273)[0]/S_rated])
#     P6max.append([k+0.01,PV.find_opt(G6[k],30+273)[0]/S_rated])
#     P8max.append([k+0.01,PV.find_opt(G8[k],30+273)[0]/S_rated])
# np.savetxt("Input/P1max.csv", P1max, delimiter=",") 
# np.savetxt("Input/P6max.csv", P6max, delimiter=",") 
# np.savetxt("Input/P8max.csv", P8max, delimiter=",")
# Out:
# x value is: [ 4.16666694e-02  2.71096293e-09  1.04166670e-01  1.61009323e-09
#  -6.31835322e-13  6.25000015e-01  5.42030517e+00 -1.37056642e+01
#   9.55599466e+00 -2.92978858e+00]
# [16772.4568269] [16772.44994801]
# x value is: [ 4.16666700e-02  3.08798160e-09  1.04166671e-01  1.70339328e-09
#   1.90172478e-12  6.25000018e-01  7.54924784e+00 -2.00658140e+01
#   1.57772709e+01 -4.98454777e+00]
# [17651.90626857] [17651.89942457]
# 138.98426556229097
# 11812.410221992996 -3837.0390763001883 16740
# x value is: [ 4.16666700e-02  3.07339867e-09  1.04166671e-01  1.68873553e-09
#   1.45293559e-13  6.25000018e-01  7.60909653e+00 -2.02471671e+01
#   1.59604348e+01 -5.04620719e+00]
# [17631.90710087] [17631.90010961]
# -10324.64065801763
# -1145462.8735361681 506467649981066.9 16740
# x value is: [ 4.16666700e-02  3.06978239e-09  1.04166671e-01  1.68359664e-09
#  -2.54657218e-13  6.25000018e-01  7.66985187e+00 -2.04316225e+01
#   1.61470911e+01 -5.10916341e+00]
# [17611.10017435] [17611.0931264]
# -10325.307664062359
# -1145553.4445268158 512951192180448.75 16740
# x value is: [ 4.16666699e-02  3.06651523e-09  1.04166671e-01  1.68027723e-09
#   1.19856983e-12  6.25000018e-01  7.73191507e+00 -2.06204195e+01
#   1.63385169e+01 -5.17385534e+00]
# [17589.47673509] [17589.46975386]
# -10322.728528439768
# -1145203.2423722956 518645131229825.56 16740

# %%
# import numpy
# from numpy.distutils.system_info import get_info
# blas_info = get_info('blas_opt')
# print(blas_info)
# lapack_info = get_info('lapack_opt')
# print(lapack_info)

# import numpy as np
# np.show_config()

# import scipy
# scipy.__version__

# %%
V*I
# Out:
# array([16397.24450726, 16414.4031568 , 16431.22556086, 16447.70728677,
#        16463.84385176, 16479.63072266, 16495.06331549, 16510.13699514,
#        16524.847075  , 16539.18881664, 16553.15742943, 16566.74807023,
#        16579.95584302, 16592.77579861, 16605.20293427, 16617.23219345,
#        16628.8584654 , 16640.07658492, 16650.881332  , 16661.26743154,
#        16671.22955302, 16680.76231028, 16689.86026112, 16698.51790712,
#        16706.72969329, 16714.49000785, 16721.79318193, 16728.63348933,
#        16735.00514626, 16740.90231113, 16746.31908426, 16751.24950768,
#        16755.68756494, 16759.62718082, 16763.06222121, 16765.98649288,
#        16768.39374327, 16770.27766034, 16771.63187242, 16772.44994801,
#        17902.60525093, 17906.38217453, 17909.62499832, 17912.3272013 ,
#        17914.48220132, 17916.08335494, 17917.12395733, 17917.59724209,
#        17917.4963812 , 17916.81448489, 17915.54460158, 17913.67971776,
#        17911.21275798, 17908.13658476, 17904.44399857, 17900.12773782,
#        17895.18047882, 17889.5948358 , 17883.36336093, 17876.47854432,
#        17868.93281411, 17860.71853649, 17851.82801579, 17842.25349456,
#        17831.98715368, 17821.02111247, 17809.34742883, 17796.95809938,
#        17783.84505963, 17770.00018418, 17755.41528686, 17740.08212101,
#        17723.99237967, 17707.13769586, 17689.50964278, 17671.09973417,
#        17651.89942457, 17631.90010961, 17611.0931264 , 17589.46975386])
